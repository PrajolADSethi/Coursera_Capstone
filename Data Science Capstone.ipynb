# %% [markdown]
# # Coursera Capstone Project

# %% [markdown]
# Author : Prajol Sethi

# %% [markdown]
# Project Description : This notebook will be used for getting a solution to the stated problem in the capstone using concepts of data science , machine learning , alogorithms like clustering and data visulization as well.

# %%
#importing libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ### Test

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
