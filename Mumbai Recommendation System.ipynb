# %% [markdown]
# # The battle of Neighboorhoods

# %% [markdown]
# ## Week 4 Part A

# %% [markdown]
# ## Title Restaurant Recommendation System in Mumbai

# %% [markdown]
# ##### Author: Prajol Sethi

# %% [markdown]
# ## Problem Background

# %% [markdown]
# Mumbai, formerly Bombay, city, capital of Maharashtra state, southwestern India. It is the country’s financial and commercial centre and its principal port on the Arabian Sea.
# The current populatio of the city is near about 2 crore like as of 2020 .
# More than that Mumbai is famous for various for several things like Bollywood Industry , Mumbai Police , Marine Drive, Lal Bagh cha Raja , local trains and a long list to go but the most important thing for which MUmbai is famous for is its food .
# From a 6 ruppee vadapav to lakhs of ruppees of cusienes of 5 stars like Taj .Even from a completely delicious jain food to hardcore non-veg any dish you just name it and you get it here.
# Mumbai can also be called a foodie's paradise because of its vast variety of foods and edibles with a touch of Mumbaikar's uniqueness and tradition

# %% [markdown]
# ## Problem Description

# %% [markdown]
# Mumbai is a very huge city and also densely populated,nearly seven time the population of whole New Zeland, so it is difficult to find best restaurant for a particular dish.  This is very hectic and plus you get to experience very different types of environment, of which you may not have much knowledge about. In such situation, food can be an important factor for decided how you rate your trips and plus also recommmending it to the people. Food can also attract people around the world to try it out if it were to be the best. In such scenarios, we need to find the right place, at reasonable cost, to serve us the best possible way. So there are few questions that must be addresed, such as :
#
# 1. Types of restaurant on basis of food origin ?
# 2. Which is the most nearest to me with good rating ?
# 3. How many "similar" restaurants are available near by me ?
# 4. Do the "similar" restaurants cost more ? if so, what speciality do that have ?
# To address such question, XYZ company's manager decides to allocate this project to me not just to find out solutions to the questions but also build a system that can help in recommending new places based on their rankings compared to the previously visited by me.
#
# Expectations from this recommender system is to get answer for the questions, and in such a way that it uncovers all the perspective of managing recommendations. It is sighted to show :
#
# 1. What types of restaurants are present in a particular area ?
# 2. Where are the similar restaurant present based on a preference to particular food ?
# 3. How do different restaurants rank with respect to my preferences ?

# %% [markdown]
# ##  Target Audience

# %% [markdown]
# Target audiences for this project does not limit to a type of person. People could simply decide to look for a similar restaurant all the time because they are addicted to a specific category of food. Even nowadays it has become a habit of people to review places based on food quality,ambience,crowd,money and service.Even people who rarely use restaurants would prefer to have the most rated restaurants nearby them and all this could be easily handed by our recommender system. So target for this project is basically everyone who is exploring different places or similar places.

# %% [markdown]
# ## Success Rate
